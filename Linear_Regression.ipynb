# %% [markdown]
# <a href="https://colab.research.google.com/github/ZebaFatima639/Data-Cleaning-Data-Preprocessing/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
sns.jointplot(x='price', y='area', data=df)

# %%
sns.jointplot(x='area', y='price', data=df, alpha = 0.5)

# %%
sns.pairplot(df, kind ='scatter',plot_kws={'alpha':0.5})

# %%
sns.lmplot(x='area', y='price', data=df, hue='mainroad')

# %%
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True)
# Out:
# <Axes: >

# %%
X = df[['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']]
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 227  4690000  6000         2          1        1      yes        no      yes
# 319  4060000  3000         4          1        3      yes        no      yes
# 367  3675000  3630         2          1        1      yes        no       no
# 515  2450000  3210         3          1        2      yes        no      yes
# 143  5600000  4800         5          2        3       no        no      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 316  4060000  5900         4          2        2       no        no      yes
# 393  3500000  7424         3          1        1       no        no       no
# 75   6650000  4260         4          2        2      yes        no       no
# 337  3920000  2145         4          2        1      yes        no      yes
# 523  2380000  2787         4          2        2      yes        no       no
#
# ...

# %%
X_test
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 225  4753000  6440         2          1        1      yes        no       no
# 18   8890000  4600         3          2        2      yes       yes       no
# 48   7455000  4300         3          2        2      yes        no      yes
# 355  3773000  8250         3          1        1      yes        no       no
# 350  3780000  3420         2          1        2      yes        no       no
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 401  3500000  9500         3          1        2      yes        no       no
# 189  5040000  3540         2          1        1       no       yes      yes
# 43   7700000  6000         4          2        4      yes        no       no
# 36   8043000  7482         3          2        3      yes        no       no
# 405  3465000  3060         3          1        1      yes        no       no
#
# ...

# %%
y_train
# Out:
# 227    4690000
# 319    4060000
# 367    3675000
# 515    2450000
# 143    5600000
#         ...
# 316    4060000
# 393    3500000
# 75     6650000
# 337    3920000
# 523    2380000
# Name: price, Length: 381, dtype: int64

# %%
y_test
# Out:
# 225    4753000
# 18     8890000
# 48     7455000
# 355    3773000
# 350    3780000
#         ...
# 401    3500000
# 189    5040000
# 43     7700000
# 36     8043000
# 405    3465000
# Name: price, Length: 164, dtype: int64

# %%
#training the model
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(lm.coef_, X_train.columns, columns=['Coefficient'])

# %%
coeff_df
# Out:
#                                   Coefficient
# price                            1.000000e+00
# area                            -8.620899e-16
# bedrooms                        -4.710298e-12
# bathrooms                       -2.420106e-11
# stories                         -8.256571e-12
# parking                          5.928197e-12
# mainroad_yes                     8.001807e-12
# guestroom_yes                   -9.458728e-12
# basement_yes                     2.700415e-11
# hotwaterheating_yes              6.111526e-11
# airconditioning_yes              1.620284e-11
# prefarea_yes                    -6.980240e-12
# furnishingstatus_semi-furnished -1.223178e-12
# furnishingstatus_unfurnished    -7.924715e-12

# %%
#predictions
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([ 4753000.,  8890000.,  7455000.,  3773000.,  3780000.,  3703000.,
#         7910000.,  3500000.,  4098500.,  5250000.,  4200000.,  9870000.,
#         3290000.,  4095000.,  6230000.,  5229000.,  3150000.,  6580000.,
#         3570000.,  4473000.,  6020000.,  5950000.,  6615000.,  5950000.,
#         4550000.,  4403000.,  3010000.,  4200000.,  3640000.,  7350000.,
#         5950000.,  2100000.,  8295000.,  3150000.,  5460000.,  3360000.,
#         4830000.,  4795000.,  3500000.,  2590000.,  4585000., 11410000.,
#         5075000.,  4200000.,  2660000.,  3430000.,  3395000.,  4690000.,
#         6293000.,  4200000.,  3780000.,  5145000., 12250000.,  3290000.,
#         5215000.,  4060000.,  3353000.,  4900000.,  4480000.,  3640000.,
#         3129000.,  8575000.,  8400000.,  4340000.,  4620000.,  6160000.,
#         3332000.,  7000000.,  3605000.,  4480000.,  7070000.,  9310000.,
#         4270000.,  3360000.,  3150000.,  4893000.,  2450000.,  2240000.,
# ...

# %%
plt.scatter(y_test, predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

# %%
print('MAE:', mean_absolute_error(y_test, predictions))
print('MSE:', mean_squared_error(y_test, predictions))
print('RMSE:', math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# MAE: 5.749781139013244e-10
# MSE: 7.751384434385695e-19
# RMSE: 8.804194701609963e-10

# %%
#residuals
residuals = y_test - predictions
residuals
# Out:
# 225    0.000000e+00
# 18    -1.862645e-09
# 48    -1.862645e-09
# 355    0.000000e+00
# 350    0.000000e+00
#            ...
# 401    4.656613e-10
# 189    0.000000e+00
# 43    -1.862645e-09
# 36    -1.862645e-09
# 405    4.656613e-10
# Name: price, Length: 164, dtype: float64

# %%
sns.distplot(residuals, bins=8)
# 0r sns.distplot((y_test-predictions), bins=8)
# Out:
# /tmp/ipython-input-785447747.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, bins=8)
# <Axes: xlabel='price', ylabel='Density'>

# %%
import pylab
import scipy.stats as stats
stats.probplot(residuals, dist="norm", plot=pylab)
pylab.show()
